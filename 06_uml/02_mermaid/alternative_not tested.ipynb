# %% [markdown]
# # Bug
#
# \# TODO: Module installations listed on this page ended up dependancy errors and during the next kernel startup, the following error showed up:
#
#   "ModuleNotFoundError: No module named 'resource'\r\n" when launching jupyter kernel. Hence had to reinstall jupyter notebook.

# %% [markdown]
# Ref: https://nbviewer.org/github/bollwyvl/nb-mermaid/blob/master/notebooks/README.ipynb
#
# While `nb-mermaid` will work with any Jupyter kernel, IPython provides a way to capture loading an extension directly in a cell as a `%linemagic`:

# %%
# %reload_ext mermaid
# Out:
# The kernel failed to start due to the missing module ''resource''. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %% [markdown]
# <div class="mermaid">
# graph LR
#     a --> b
# </div>

# %% [markdown]
# If you take a look at the `ipynb` source, you'll see this embeds a tiny bit of javascript that will first try to hit your server's `nbextensions` directory, but failing that will fall back to the nb-mermaid github repository. This means you can use it to publish on [nbviewer.jupyter.org](http://nbviewer.jupyter.org).

# %%
# %reload_ext mermaid

# %%
# %%javascript
# IPython.load_ipython_extensions(["nb-mermaid/nb-mermaid"]);
#
# pie title Pets adopted by volunteers
#     "Dogs" : 386
#     "Cats" : 85
#     "Rats" : 15
